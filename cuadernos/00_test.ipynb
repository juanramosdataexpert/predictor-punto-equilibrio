# %%
import pandas as pd

df = pd.read_csv('../datos/crudos/variables_financieras_sec.csv')
df.head()
# Out:
#         start         end         val                  accn      fy  fp  form  \
# 0  2008-01-01  2008-06-30  2240000000  0001104659-09-046329  2009.0  Q2  10-Q
# 1  2008-01-01  2008-09-30  3408000000  0001104659-09-061503  2009.0  Q3  10-Q
# 2  2009-01-01  2009-03-31   695000000  0001104659-10-025776  2010.0  Q1  10-Q
# 3  2009-01-01  2009-06-30  2161000000  0001104659-09-046329  2009.0  Q2  10-Q
# 4  2009-01-01  2009-06-30  2161000000  0001104659-10-041912  2010.0  Q2  10-Q
#
#         filed     frame ticker       sector       variable
# 0  2009-07-31       NaN    MMM  Industrials  fcf_operativo
# 1  2009-10-30       NaN    MMM  Industrials  fcf_operativo
# 2  2010-05-05  CY2009Q1    MMM  Industrials  fcf_operativo
# 3  2009-07-31       NaN    MMM  Industrials  fcf_operativo
# 4  2010-08-04       NaN    MMM  Industrials  fcf_operativo
